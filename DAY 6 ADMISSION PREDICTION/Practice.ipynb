# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\lucius seneca\CampusX\100 Days of DL\DAY 6 ADMISSION PREDICTION\Admission_Predict_Ver1.1.csv")

# %%
df.isnull().sum()
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.head(5)
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
df.drop(columns=["Serial No."],inplace=True)

# %%
df.head(5)
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0        337          118                  4  4.5   4.5  9.65         1
# 1        324          107                  4  4.0   4.5  8.87         1
# 2        316          104                  3  3.0   3.5  8.00         1
# 3        322          110                  3  3.5   2.5  8.67         1
# 4        314          103                  2  2.0   3.0  8.21         0
#
#    Chance of Admit
# 0              0.92
# 1              0.76
# 2              0.72
# 3              0.80
# 4              0.65

# %%
df
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0          337          118                  4  4.5   4.5  9.65         1
# 1          324          107                  4  4.0   4.5  8.87         1
# 2          316          104                  3  3.0   3.5  8.00         1
# 3          322          110                  3  3.5   2.5  8.67         1
# 4          314          103                  2  2.0   3.0  8.21         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 495        332          108                  5  4.5   4.0  9.02         1
# 496        337          117                  5  5.0   5.0  9.87         1
# 497        330          120                  5  4.5   5.0  9.56         1
# 498        312          103                  4  4.0   5.0  8.43         0
# 499        327          113                  4  4.5   4.5  9.04         0
#
#      Chance of Admit
# 0                0.92
# 1                0.76
# ...

# %%
X=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42)

# %%
X_train
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research
# 227        312          110                  2  3.5   3.0  8.53         0
# 417        316          103                  3  3.5   2.0  7.68         0
# 203        334          120                  5  4.0   5.0  9.87         1
# 126        323          113                  3  4.0   3.0  9.32         1
# 329        297           96                  2  2.5   1.5  7.89         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 106        329          111                  4  4.5   4.5  9.18         1
# 270        306          105                  2  2.5   3.0  8.22         1
# 348        302           99                  1  2.0   2.0  7.25         0
# 435        309          105                  2  2.5   4.0  7.68         0
# 102        314          106                  2  4.0   3.5  8.25         0
#
# [375 rows x 7 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()

# %%
X_train_scaled=scaler.fit_transform(X_train)

# %%
X_test_scaled=scaler.transform(X_test)

# %%
X_test_scaled
# Out:
# array([[ 0.87234043,  0.85714286,  0.75      ,  0.75      ,  0.57142857,
#          0.87820513,  1.        ],
#        [ 0.44680851,  0.57142857,  0.75      ,  0.875     ,  0.71428571,
#          0.71794872,  1.        ],
#        [ 0.46808511,  0.46428571,  0.25      ,  0.25      ,  0.28571429,
#          0.2724359 ,  0.        ],
#        [ 0.40425532,  0.60714286,  0.5       ,  0.5       ,  0.42857143,
#          0.60576923,  0.        ],
#        [ 0.70212766,  0.71428571,  0.5       ,  0.625     ,  0.42857143,
#          0.72115385,  1.        ],
#        [ 0.76595745,  0.67857143,  0.75      ,  0.875     ,  0.71428571,
#          0.77884615,  1.        ],
#        [-0.06382979,  0.28571429,  0.        ,  0.125     ,  0.14285714,
#          0.24358974,  0.        ],
#        [ 0.17021277,  0.5       ,  0.75      ,  0.375     ,  0.42857143,
#          0.53525641,  0.        ],
#        [ 0.53191489,  0.60714286,  0.5       ,  0.625     ,  0.71428571,
# ...

# %%
import tensorflow
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense

# %%
model=Sequential()

# %%
model.add(Dense(15,activation="relu",input_dim=7))
model.add(Dense(8,activation="relu"))
model.add(Dense(1,activation="linear"))
# Out:
# c:\Users\lucius seneca\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 8)              │            64 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 8)              │            72 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │             9 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 8)              │            16 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 8)              │            72 │
# ...

# %%
model.compile(loss="mean_squared_error",optimizer="Adam")

# %%
history=model.fit(X_train_scaled,y_train,epochs=6,validation_split=0.2)
# Out:
# Epoch 1/6
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0035 - val_loss: 0.0044
# Epoch 2/6
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0039 - val_loss: 0.0046
# Epoch 3/6
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0035 - val_loss: 0.0045
# Epoch 4/6
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0029 - val_loss: 0.0044
# Epoch 5/6
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0030 - val_loss: 0.0044
# Epoch 6/6
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0032 - val_loss: 0.0044

# %%
y_pred=model.predict(X_test_scaled)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
y_pred
# Out:
# array([[0.9213416 ],
#        [0.7957609 ],
#        [0.5903171 ],
#        [0.70237774],
#        [0.8183251 ],
#        [0.85563177],
#        [0.43472674],
#        [0.63338524],
#        [0.82168216],
#        [0.83153313],
#        [0.7109863 ],
#        [0.72030115],
#        [0.62468094],
#        [0.939957  ],
#        [0.82660085],
#        [0.48302746],
#        [0.83983296],
#        [0.64998883],
#        [0.53972566],
#        [0.5737156 ],
#        [0.6394614 ],
#        [0.48747897],
#        [0.73677593],
#        [0.7723775 ],
#        [0.7844892 ],
#        [0.5583101 ],
#        [0.9493936 ],
#        [0.8297377 ],
#        [0.6445665 ],
#        [0.7060997 ],
#        [0.50561404],
#        [0.70725274],
#        [0.551993  ],
#        [0.87251216],
#        [0.650848  ],
#        [0.7338281 ],
#        [0.56241447],
#        [0.96464396],
#        [0.64633715],
#        [0.6840449 ],
#        [0.9388859 ],
#        [0.6519696 ],
#        [0.6470962 ],
# ...

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.757657664525875
